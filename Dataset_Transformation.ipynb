# %% [markdown]
# # Fortune 500 Companies Database

# %% [markdown]
# ### This notebook Transforms the following data into fortune500_db.sqlite
# - Fortune 500 companies
# - Fortune 500 stock values
# - Fortune 500 job postings
# - Fortune 500 job reviews
# - Global Exchange Rates
# - United States Population by city

# %% [markdown]
# ## Import necessary libraries:

# %%
import pandas as pd

# %%
# Imports the method used for connecting to DBs
from sqlalchemy import create_engine

# Imports the methods needed to abstract classes into tables
from sqlalchemy.ext.declarative import declarative_base

# Allow us to declare column types
from sqlalchemy import Column, Integer, String, Float

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()

# %% [markdown]
# ## Create engine and connection to sqlite:

# %%
from config import username, passwd, location, database

engine = create_engine(f"mysql://{username}:{passwd}@{location}/{database}")
conn = engine.connect()

# %% [markdown]
# ## Create declarative base and create session to add to database:

# %%
Base = declarative_base()

Base.metadata.create_all(engine)

from sqlalchemy.orm import Session
session = Session(bind=engine)

# %% [markdown]
# ## Import all csv files into a dataframe:

# %% [markdown]
# #### Start with fortune 500 comapnies and proceed with others.

# %%
fortune500_path = "./Data/Fortune_500_list_databahn_2018.csv"

# %%
fortune500_df = pd.read_csv(fortune500_path, encoding = "ISO-8859-1")
fortune500_df.columns
# Out:
# Index(['Fortune  Rank (2018)', 'Company Name', 'Ticker Symbol',
#        'Fortune Rank (2017)', 'Revenues', 'Revenues change', 'Profits',
#        'Profit Change', 'Assets', 'Market Value', 'Employee Count', 'CEO Name',
#        'CEO Title', 'Sector', 'Industry', 'HQ Location', 'Website URL',
#        'Years on Fortune List', 'Fortune URL'],
#       dtype='object')

# %% [markdown]
# ## Edit column headers to be friendlier to SQL.

# %%
fortune500_df.rename(columns={
    "Fortune  Rank (2018)":"fortune_rank",
    "Company Name":"name",
    "Ticker Symbol":"ticker",
    "Fortune Rank (2017)":"rank_2017",
    "Revenues":"revenues",
    "Revenues change":"revenue_change",
    "Profits":"profits",
    "Profit Change":"profit_change",
    "Assets":"assets",
    "Market Value":"market_value",
    "Employee Count":"num_employees",
    "CEO Name":"ceo_name",
    "CEO Title":"ceo_title",
    "Sector":"sector",
    "HQ Location":"hq_location",
    "Website URL":"url",
    "Years on Fortune List":"years_on_fortune_list",
    "Fortune URL":"fortune_url"
}, inplace=True)

# %%
# Check all rows with \x92,  there is a string error: 
fortune500_df[fortune500_df['name'].str.contains("\x92")==True]
# Out:
#      fortune_rank                    name ticker  rank_2017 revenues  \
# 39           40.0                  Lowes    LOW       40.0  $68,619
# 119         120.0                  Macys      M      110.0  $24,837
# 130         131.0              McDonalds    MCD      112.0  $22,820
# 156         157.0                  Kohls    KSS      150.0  $19,095
# 215         216.0            Land OLakes    NaN      209.0  $13,740
# 328         329.0     OReilly Automotive   ORLY      323.0   $8,978
# 338         339.0      Peter Kiewit Sons    NaN      324.0   $8,678
# 339         340.0   Dicks Sporting Goods    DKS      340.0   $8,591
# 424         425.0  Caseys General Stores   CASY      423.0   $6,641
# 438         439.0               Dillards    DDS      417.0   $6,423
#
#     revenue_change   profits profit_change   assets market_value  \
# 39            5.5%  $3,447.0         11.4%  $35,291      $72,812
# 119          -3.7%  $1,547.0        149.9%  $19,381       $9,065
# 130          -7.3%  $5,192.3         10.8%  $33,804     $124,244
# 156           2.2%    $859.0         54.5%  $13,340      $11,021
# 215           3.8%    $314.2         28.3%   $9,509          NaN
# 328           4.5%  $1,133.8          9.3%   $7,572      $20,607
# 338           1.2%    $371.0         -6.3%   $5,710          NaN
# 339           8.4%    $323.4         12.5%   $4,204       $3,765
# 424           5.3%    $177.5        -21.5%   $3,020       $4,120
# 438           0.1%    $221.3         30.8%   $3,673       $2,289
#
#     num_employees                   ceo_name  \
# 39        255,000          Robert A. Niblock
# 119       130,000           Jeffrey Gennette
# 130       235,000     Stephen J. Easterbrook
# 156        85,000           Michelle D. Gass
# 215        10,000  Christopher J. Policinski
# 328        60,365         Gregory D. Johnson
# 338        22,000          Bruce E. Grewcock
# 339        30,300            Edward W. Stack
# 424        25,463           Terry W. Handley
# 438        31,400      William T. Dillard II
#
#                                          ceo_title  \
# 39   Chairman, President & Chief Executive Officer
# 119             Chairman & Chief Executive Officer
# 130  President, Chief Executive Officer & Director
# 156             Chairman & Chief Executive Officer
# 215  President, Chief Executive Officer & Director
# 328  President, Chief Executive Officer & Director
# 338  President, Chief Executive Officer & Director
# 339             Chairman & Chief Executive Officer
# 424  President, Chief Executive Officer & Director
# 438             Chairman & Chief Executive Officer
#
#                             sector                    Industry  \
# 39                       Retailing  Specialty Retailers: Other
# 119                      Retailing       General Merchandisers
# 130  Hotels, Restaurants & Leisure               Food Services
# 156                      Retailing       General Merchandisers
# 215      Food, Beverages & Tobacco      Food Consumer Products
# 328                      Retailing  Specialty Retailers: Other
# 338     Engineering & Construction   Engineering, Construction
# 339                      Retailing  Specialty Retailers: Other
# 424                      Retailing  Specialty Retailers: Other
# 438                      Retailing       General Merchandisers
#
#                hq_location                            url  \
# 39       Mooresville, N.C.           http://www.lowes.com
# 119             Cincinnati        http://www.macysinc.com
# 130        Oak Brook, Ill.  http://www.aboutmcdonalds.com
# 156  Menomonee Falls, Wis.           http://www.kohls.com
# 215     Arden Hills, Minn.   http://www.landolakesinc.com
# 328       Springfield, Mo.     http://www.oreillyauto.com
# 338                  Omaha          http://www.kiewit.com
# 339        Coraopolis, Pa.           http://www.dicks.com
# 424           Ankeny, Iowa          http://www.caseys.com
# 438      Little Rock, Ark.        http://www.dillards.com
#
#      years_on_fortune_list                                        fortune_url
# 39                    24.0               http://fortune.com/fortune500/lowes/
# 119                   24.0               http://fortune.com/fortune500/macys/
# 130                   24.0           http://fortune.com/fortune500/mcdonalds/
# 156                   21.0               http://fortune.com/fortune500/kohls/
# 215                   16.0         http://fortune.com/fortune500/land-olakes/
# 328                    9.0  http://fortune.com/fortune500/oreilly-automotive/
# 338                   19.0   http://fortune.com/fortune500/peter-kiewit-sons/
# 339                    9.0  http://fortune.com/fortune500/dicks-sporting-g...
# 424                    8.0  http://fortune.com/fortune500/caseys-general-s...
# 438                   24.0            http://fortune.com/fortune500/dillards/

# %%
# replace these rows with "". 
fortune500_df["name"].replace({'\x92|\x93|\x94':''}, regex=True, inplace=True)
fortune500_df[fortune500_df['name'].str.contains("\x92")==True]
# Out:
# Empty DataFrame
# Columns: [fortune_rank, name, ticker, rank_2017, revenues, revenue_change, profits, profit_change, assets, market_value, num_employees, ceo_name, ceo_title, sector, Industry, hq_location, url, years_on_fortune_list, fortune_url]
# Index: []

# %%
# Check to see if it was fixed:
fortune500_df.at[271,"name"]
# Out:
# 'Toys R Us'

# %% [markdown]
# ## Push DataFrame to sqlite and check to see if written.

# %%
fortune500_df.set_index("fortune_rank", inplace=True)
fortune500_df.to_sql("fortune500_companies", conn, if_exists="replace")

# %% [markdown]
# Note: If the datatypes in SQL are set, this should be "append" and not "replace".
# - Replace will rewrite the data types if they are defined in sql.

# %%
f500 = pd.read_sql_query("select * from fortune500_companies", conn)

# %%
f500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 19 columns):
# fortune_rank             500 non-null float64
# name                     502 non-null object
# ticker                   471 non-null object
# rank_2017                495 non-null float64
# revenues                 500 non-null object
# revenue_change           497 non-null object
# profits                  500 non-null object
# profit_change            436 non-null object
# assets                   500 non-null object
# market_value             472 non-null object
# num_employees            500 non-null object
# ceo_name                 500 non-null object
# ceo_title                500 non-null object
# sector                   500 non-null object
# Industry                 500 non-null object
# hq_location              500 non-null object
# url                      500 non-null object
# years_on_fortune_list    500 non-null float64
# fortune_url              500 non-null object
# dtypes: float64(3), object(16)
# memory usage: 75.0+ KB

# %% [markdown]
# ## Add other datasets to database:

# %%
stock_values_path = "./Data/stock_values.csv"

# %%
stock_values_df = pd.read_csv(stock_values_path, encoding = "ISO-8859-1")
stock_values_df.head()
# Out:
#    Unnamed: 0 symbol        date   open    high      low  close    volume
# 0           0    WMT  2018-10-26  98.81  99.670  98.0200  98.94  14925551
# 1           1    WMT  2018-10-25  98.01  99.480  97.0000  99.18  10737074
# 2           2    WMT  2018-10-24  97.50  99.170  97.2750  97.56  10364712
# 3           3    WMT  2018-10-23  96.50  97.985  96.1100  97.80   9405824
# 4           4    WMT  2018-10-22  97.34  97.580  96.7434  97.14   7122857

# %% [markdown]
# ### Rename columns for sql:

# %%
stock_values_df.rename(columns={
    "Unnamed: 0":"id",
    "symbol":"ticker"
}, inplace=True)

# %%
stock_values_df.set_index("id", inplace=True)
stock_values_df.head()
# Out:
#    ticker        date   open    high      low  close    volume
# id
# 0     WMT  2018-10-26  98.81  99.670  98.0200  98.94  14925551
# 1     WMT  2018-10-25  98.01  99.480  97.0000  99.18  10737074
# 2     WMT  2018-10-24  97.50  99.170  97.2750  97.56  10364712
# 3     WMT  2018-10-23  96.50  97.985  96.1100  97.80   9405824
# 4     WMT  2018-10-22  97.34  97.580  96.7434  97.14   7122857

# %%
stock_values_df.to_sql("stock_values", conn, if_exists="replace")

# %% [markdown]
# ## Add Apple Reviews

# %%
apple_reviews_path = "./Data/Apple_reviews.csv"
apple_reviews_df = pd.read_csv(apple_reviews_path, encoding = "ISO-8859-1")
apple_reviews_df.head()
# Out:
#    Unnamed: 0 company  rating_number                     reviewer  \
# 0           0   Apple            5.0  Technical/ Sales Specialist
# 1           0   Apple            3.0            Software Engineer
# 2           0   Apple            5.0         Technical Specialist
# 3           0   Apple            4.0            Technical Advisor
# 4           0   Apple            3.0           Material Handler 3
#
#                                     review_job_title review_job_location  \
# 0  Technical/ Sales SpecialistÂ (Former Employee)...          Edison, NJ
# 1       Software EngineerÂ (Current Employee) â Â        Cupertino, CA
# 2    Technical SpecialistÂ (Current Employee) â Â       Northridge, CA
# 3       Technical AdvisorÂ (Current Employee) â Â              At Home
# 4       Material Handler 3Â (Former Employee) â Â        Elk Grove, CA
#
#                                          review_text review_date_created  \
# 0  There is a lot to learn at this company. There...  September 26, 2018
# 1  Your experience at Apple really depends only w...    October 29, 2018
# 2  Apple is a company that believes in their cons...    October 28, 2018
# 3  A typical day at work is an 8-10 hour day, shi...    October 28, 2018
# 4  I was very excited when I started here. It is ...    October 28, 2018
#
#    page_retrieved
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %%
apple_reviews_df.drop(columns=["Unnamed: 0", "review_job_title", "page_retrieved"], inplace=True)
apple_reviews_df.head()
# Out:
#   company  rating_number                     reviewer review_job_location  \
# 0   Apple            5.0  Technical/ Sales Specialist          Edison, NJ
# 1   Apple            3.0            Software Engineer       Cupertino, CA
# 2   Apple            5.0         Technical Specialist      Northridge, CA
# 3   Apple            4.0            Technical Advisor             At Home
# 4   Apple            3.0           Material Handler 3       Elk Grove, CA
#
#                                          review_text review_date_created
# 0  There is a lot to learn at this company. There...  September 26, 2018
# 1  Your experience at Apple really depends only w...    October 29, 2018
# 2  Apple is a company that believes in their cons...    October 28, 2018
# 3  A typical day at work is an 8-10 hour day, shi...    October 28, 2018
# 4  I was very excited when I started here. It is ...    October 28, 2018

# %%
apple_reviews_df.index.name = 'id'
apple_reviews_df.to_sql("company_reviews", conn, if_exists="replace")

# %% [markdown]
# ## Add Exchange Rates

# %%
exchange_path = "./Data/exchange.csv"
exchange_df = pd.read_csv(exchange_path, encoding = "ISO-8859-1")
exchange_df.head()
# Out:
#    Unnamed: 0 fromcode           fromname tocode                toname  \
# 0           0      AFN     Afghan Afghani    USD  United States Dollar
# 1           1      ARS     Argentine Peso    USD  United States Dollar
# 2           2      AWG      Aruban Florin    USD  United States Dollar
# 3           3      AUD  Australian Dollar    USD  United States Dollar
# 4           4      AZN  Azerbaijani Manat    USD  United States Dollar
#
#        rate        lastrefreshed
# 0  0.013351  2018-10-29 23:24:59
# 1  0.027115  2018-10-29 23:25:09
# 2  0.561798  2018-10-29 23:25:20
# 3  0.706015  2018-10-29 23:25:30
# 4  0.588408  2018-10-29 23:25:40

# %%
exchange_df.rename(columns={
    "Unnamed: 0":"id",
    "fromcode":"from",
    "tocode":"to",
    "lastrefreshed":"last_refreshed"
}, inplace=True)

# %%
exchange_df.set_index("id", inplace=True)

# %%
exchange_df.to_sql("exchange", conn, if_exists="replace")

# %% [markdown]
# ## Add Indeed file:
# note this is a dat file

# %%
indeed_path = "./Data/indeed.dat"
indeed_df = pd.read_csv(indeed_path)

indeed_df.head()
# Out:
#    Unnamed: 0         age  company  \
# 0           0  2 days ago  Walmart
# 1           1  2 days ago  Walmart
# 2           2  2 days ago  Walmart
# 3           3  2 days ago  Walmart
# 4           4  2 days ago  Walmart
#
#                                                 desc              jcid  \
# 0  2 years experience with ETL, data modeling, SQ...  822bc5d9a49270ea
# 1  Fluency in SQL, as well as an understanding of...  822bc5d9a49270ea
# 2  Position Description As a Software Engineer II...  822bc5d9a49270ea
# 3  Position Description In this role you will · A...  822bc5d9a49270ea
# 4  Experience in RESTful Services, RDBMS, NoSql, ...  822bc5d9a49270ea
#
#                jkid  job_no                    loc  query_date query_time  \
# 0  1b40383fd862d403       1  Bentonville, AR 72712  2018-10-29   20:48:18
# 1  27ec2b40b1200fe2       2    San Bruno, CA 94066  2018-10-29   20:48:18
# 2  a3747a644aa53898       3  Bentonville, AR 72712  2018-10-29   20:48:18
# 3  25492a3d97275785       4          Sunnyvale, CA  2018-10-29   20:48:18
# 4  47a8e7b1fc47f6a7       5          Sunnyvale, CA  2018-10-29   20:48:18
#
#                                      title
# 0       Business Intelligence Analyst -LEG
# 1                Product Analytics Manager
# 2                    Software Engineer III
# 3  Search/Relevance - Staff Data Scientist
# 4                  Staff Software Engineer

# %%
indeed_df.drop(columns=["query_time","desc"], inplace=True)

# %%
indeed_df.rename(columns={
    "Unnamed: 0":"id",
    "jcid":"company_id",
    "jkid":"job_id"
}, inplace=True)

# %%
indeed_df.set_index("id", inplace=True)

# %%
indeed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2831 entries, 0 to 2830
# Data columns (total 8 columns):
# age           2831 non-null object
# company       2831 non-null object
# company_id    2831 non-null object
# job_id        2831 non-null object
# job_no        2831 non-null int64
# loc           2831 non-null object
# query_date    2831 non-null object
# title         2831 non-null object
# dtypes: int64(1), object(7)
# memory usage: 199.1+ KB

# %%
indeed_df.to_sql("indeed", conn, if_exists="replace")

# %% [markdown]
# ### Add population data:

# %%
population_path = "./Data/Population_Data.csv"
population_df = pd.read_csv(population_path)

population_df.head()
# Out:
#    Rank         Name       State  2018 Population  2016 Population  \
# 0     1    New York     New York          8580015          8537673
# 1     2  Los Angeles  California          4030668          3976322
# 2     3     Chicago     Illinois          2687682          2704958
# 3     4     Houston        Texas          2340814          2303482
# 4     5      Phoenix     Arizona          1679243          1615017
#
#    2010 Census    Change  2018 Density
# 0      8175133  0.002474  11029.232132
# 1      3792621  0.006787   3320.644797
# 2      2695598 -0.003204   4564.612213
# 3      2099451  0.008038   1419.917805
# 4      1445632  0.019496   1252.474383

# %%
population_df.rename(columns={
    "Rank":"rank",
    "Name":"name",
    "State":"state",
    "2018 Population":"2018_population",
    "2016 Population":"2016_population",
    "2010 Census":"2010_population",
    "Change":"change",
    "2018 Density":"2018_density"
}, inplace=True)

# %%
population_df
# Out:
#     rank              name                 state  2018_population  \
# 0      1         New York               New York          8580015
# 1      2       Los Angeles            California          4030668
# 2      3          Chicago               Illinois          2687682
# 3      4          Houston                  Texas          2340814
# 4      5           Phoenix               Arizona          1679243
# 5      6      Philadelphia          Pennsylvania          1573688
# 6      7      San Antonio                  Texas          1541456
# 7      8         San Diego            California          1438060
# 8      9           Dallas                  Texas          1359133
# 9     10          San Jose            California          1030796
# 10    11           Austin                  Texas           983366
# 11    12      Jacksonville               Florida           907529
# 12    14       Fort Worth                  Texas           893997
# 13    13     San Francisco            California           888653
# 14    15         Columbus                   Ohio           880182
# 15    17         Charlotte        North Carolina           873363
# 16    16      Indianapolis               Indiana           860902
# 17    18           Seattle            Washington           746046
# 18    19            Denver              Colorado           719116
# 19    20  Washington DC DC  District of Columbia           702756
# 20    21           El Paso                 Texas           692100
# 21    22            Boston         Massachusetts           687584
# 22    24         Nashville             Tennessee           673008
# 23    23           Detroit              Michigan           665713
# 24    26         Portland                 Oregon           658347
# 25    27    Oklahoma City               Oklahoma           653865
# 26    28         Las Vegas                Nevada           653840
# 27    25           Memphis             Tennessee           649243
# 28    29        Louisville              Kentucky           619287
# 29    30         Baltimore              Maryland           601188
# ..   ...               ...                   ...              ...
# 70    70           Lincoln              Nebraska           287870
# 71    74            Irvine            California           286720
# 72    72            Newark            New Jersey           283092
# 73    73            Toledo                  Ohio           276172
# 74    76           Durham         North Carolina           274006
# 75    75       Chula Vista            California           271434
# 76    78    St. Petersburg               Florida           269645
# 77    77        Fort Wayne               Indiana           267852
# 78    79       Jersey City            New Jersey           264720
# 79    80            Laredo                 Texas           262034
# 80    81           Madison             Wisconsin           260427
# 81    84        Scottsdale               Arizona           260189
# 82    82           Lubbock                 Texas           260188
# 83    85          Chandler               Arizona           254773
# 84    86              Reno                Nevada           254431
# 85    83           Buffalo              New York           254004
# 86    87          Glendale               Arizona           251269
# 87    90   North Las Vegas                Nevada           247680
# 88    91           Gilbert               Arizona           246601
# 89    89     Winston-Salem        North Carolina           245549
# 90    88           Norfolk              Virginia           243085
# 91    93        Chesapeake              Virginia           242958
# 92    92            Irving                 Texas           242873
# 93    95           Fremont            California           236566
# 94    94           Hialeah               Florida           235081
# 95    96          Garland                  Texas           232421
# 96    98          Richmond              Virginia           230254
# 97    99        Boise City                 Idaho           228900
# 98    97       Baton Rouge             Louisiana           226505
# 99   100           Spokane            Washington           221759
#
#     2016_population  2010_population    change  2018_density
# 0           8537673          8175133  0.002474  11029.232132
# 1           3976322          3792621  0.006787   3320.644797
# 2           2704958          2695598 -0.003204   4564.612213
# 3           2303482          2099451  0.008038   1419.917805
# 4           1615017          1445632  0.019496   1252.474383
# 5           1567872          1526006  0.001851   4528.337442
# 6           1492510          1327407  0.016133   1291.083266
# 7           1406630          1307402  0.011049   1709.720503
# 8           1317929          1197816  0.015392   1543.608793
# 9           1025350           945942  0.002649   2242.032634
# 10           947890           790390  0.018369   1183.592500
# 11           880619           821784  0.015049    468.669481
# 12           854113           741206  0.022815   1001.075032
# 13           870887           805235  0.010097   7314.913095
# 14           860090           787033  0.011545   1554.604787
# 15           842051           731424  0.018253   1101.358345
# 16           855164           820445  0.003344    919.628007
# 17           704352           608660  0.028747   3435.964326
# 18           693060           600158  0.018451   1811.111426
# 19           681170           601723  0.015598   4437.945855
# 20           683080           649121  0.006559   1038.335953
# 21           673184           617594  0.010582   5491.468650
# 22           660388           601222  0.009465    545.976537
# 23           672795           713777 -0.005291   1852.910235
# 24           639863           583776  0.014238   1904.617920
# 25           638367           579999  0.011993    416.389688
# 26           632912           583756  0.016264   1873.484758
# 27           652717           646889 -0.002668    789.804223
# 28           616261           597337  0.002449    906.764036
# 29           614664           620961 -0.011084   2867.667346
# ..              ...              ...       ...           ...
# 70           280364           258379  0.013209   1196.254032
# 71           266122           212375  0.037258   1688.012431
# 72           281764           277140  0.002351   4527.196450
# 73           278508           287208 -0.004211   1321.398261
# 74           263016           228330  0.020465    958.898909
# 75           267172           243916  0.007913   2111.549453
# 76           260999           244769  0.016293   1685.382794
# 77           264488           253691  0.006319    934.829660
# 78           264152           247597  0.001074   6908.465211
# 79           257156           236091  0.009395    972.108282
# 80           252551           233209  0.015353   1305.573842
# 81           246645           217385  0.026723    546.132617
# 82           252506           229573  0.014984    786.722468
# 83           247477           236123  0.014527   1514.059925
# 84           245255           225221  0.018364    904.082812
# 85           256902           261310 -0.005672   2428.548055
# 86           245895           226721  0.010809   1630.925710
# 87           238702           216961  0.018459    975.660424
# 88           237133           208453  0.019573   1399.975174
# 89           242203           229617  0.006860    715.524213
# 90           245115           242803 -0.004158   1761.666333
# 91           237940           222209  0.010435    277.115924
# 92           238289           216290  0.009527   1398.514381
# 93           233136           214089  0.007303   1179.098266
# 94           236387           224669 -0.002770   4226.314094
# 95           234943           226876 -0.005396   1573.299262
# 96           223170           204214  0.015623   1483.846075
# 97           223154           205671  0.012711   1078.027372
# 98           227715           229493 -0.002664   1017.867311
# 99           215973           208916  0.013218   1245.101203
#
# [100 rows x 8 columns]

# %%
population_df.set_index("rank", inplace=True)

# %%
population_df.to_sql("population", conn, if_exists="replace", index=True)

# %% [markdown]
# ## Close connection when complete

# %%
conn.close()
