# %% [markdown]
# # Fortune 500 and Exchange Transformations

# %% [markdown]
# This is the procedure to transform and load the fortune 500 and exchange rate datasets.
# Datasets to be included in this procedure will be:
# - List of Fortune 500 companies
# - Indeed postings per fortune 500 company
# - Stock prices for fortune 500 company
# - Exchange Rates for each country.

# %% [markdown]
# ### Import necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Create DataFrames for each dataset.

# %%
fortune500_path = "./Data/Fortune500global_old.csv" # https://www.someka.net/excel-template/fortune-500-excel-list/

# %%
fortune500_df = pd.read_csv(fortune500_path, encoding = "ISO-8859-1")
fortune500_df.head()
# Out:
#    Rank              Company Name      Country  Number of Employees  \
# 0     1                   Walmart          USA              2300000
# 1     2                State Grid        China               913546
# 2     3             Sinopec Group        China               667793
# 3     4  China National Petroleum        China              1470193
# 4     5         Royal Dutch Shell  Netherlands                84000
#
#   Previous \nRank  Revenues\n($millions) Revenue \nChange  \
# 0               1                 500343             0.03
# 1               2                 348903            0.107
# 2               3                 326953            0.222
# 3               4                 326008            0.242
# 4               7                 311870            0.299
#
#   Profits\n($millions) Profit \nChange  Assets\n($millions)
# 0                 9862          -0.277             204522.0
# 1               9533.4          -0.004             585278.0
# 2               1537.8           0.222             346545.0
# 3               -690.5           -1.37             629411.0
# 4                12977           1.837             407097.0

# %%
column_rename = {
    "Rank":"rank",
    "Company Name":"name",
    "Country":"country",
    "Number of Employees":"num_employees",
    "Previous \nRank":"previous_rank",
    "Revenues\n($millions)":"revenue_mil",
    "Revenue \nChange":"revenue_change",
    "Profits\n($millions)":"profits_mil",
    "Profit \nChange":"profit_change",
    "Assets\n($millions)":"assets_mil"
}

fortune500_df.rename(columns=column_rename, inplace=True)
fortune500_df.set_index("name", inplace=True)
fortune500_df.head(10)
# Out:
#                           rank      country  num_employees previous_rank  \
# name
# Walmart                      1          USA        2300000             1
# State Grid                   2        China         913546             2
# Sinopec Group                3        China         667793             3
# China National Petroleum     4        China        1470193             4
# Royal Dutch Shell            5  Netherlands          84000             7
# Toyota Motor                 6        Japan         369124             5
# Volkswagen                   7      Germany         642292             6
# BP                           8      Britain          74000            12
# Exxon Mobil                  9          USA          71200            10
# Berkshire Hathaway          10          USA         377000             8
#
#                           revenue_mil revenue_change profits_mil  \
# name
# Walmart                        500343           0.03        9862
# State Grid                     348903          0.107      9533.4
# Sinopec Group                  326953          0.222      1537.8
# China National Petroleum       326008          0.242      -690.5
# Royal Dutch Shell              311870          0.299       12977
# Toyota Motor                   265172          0.041     22510.1
# Volkswagen                     260028          0.082     13107.3
# BP                             244582          0.311        3389
# Exxon Mobil                    244363          0.174       19710
# Berkshire Hathaway             242137          0.083       44940
#
#                          profit_change  assets_mil
# name
# Walmart                         -0.277    204522.0
# State Grid                      -0.004    585278.0
# Sinopec Group                    0.222    346545.0
# China National Petroleum         -1.37    629411.0
# Royal Dutch Shell                1.837    407097.0
# Toyota Motor                     0.332    473133.0
# Volkswagen                       1.208    506956.0
# BP                               28.47    276515.0
# Exxon Mobil                      1.514    348691.0
# Berkshire Hathaway               0.867    702095.0

# %% [markdown]
# ### Load dataset into MySQL with sqlite

# %%
from config import username, passwd, location, database
import pymysql
pymysql.install_as_MySQLdb()

# %%
# Imports the method used for connecting to DBs
from sqlalchemy import create_engine

# Imports the methods needed to abstract classes into tables
from sqlalchemy.ext.declarative import declarative_base

# Allow us to declare column types
from sqlalchemy import Column, Integer, String, Float

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()

# %%
Base = declarative_base()

class Fortune500(Base):
    __tablename__ = "fortune500_companies"
    name = Column(String(255), primary_key=True)
    rank = Column(String(255))
    country = Column(String(255))
    num_employees = Column(Float)
    previous_rank = Column(String(255))
    revenue_mil = Column(Integer)
    revenue_change = Column(String(255))
    profits_mil = Column(String(255))
    profit_change = Column(String(255))
    assets_mil = Column(String(255))

# %%
engine = create_engine("sqlite:///fortune500_db.sqlite")
conn = engine.connect()

Base.metadata.create_all(engine)

from sqlalchemy.orm import Session
session = Session(bind=engine)

# %%
index = fortune500_df.index[1]
index
# Out:
# 'State Grid'

# %%
# Create a forloop to iterate through all companies in dataset
for i in range(2,3):
    # Set the row to insert class variable
    index = fortune500_df.index[i]
    
    # Define class variables
    company = Fortune500(
        name = index,
        rank = fortune500_df.loc[index][0],
        country = fortune500_df.loc[index][1],
        num_employees = fortune500_df.loc[index][2],
        previous_rank = fortune500_df.loc[index][3],
        revenue_mil = fortune500_df.loc[index][4],
        revenue_change = fortune500_df.loc[index][5],
        profits_mil = fortune500_df.loc[index][6],
        profit_change = fortune500_df.loc[index][7],
        assets_mil = fortune500_df.loc[index][8])
    
    session.add(company)
    session.commit()
# Out:
# -------------------------------------------------------
# InvalidRequestError   Traceback (most recent call last)
# <ipython-input-37-c0c6dff5f55e> in <module>()
#      18
#      19     session.add(company)
# ---> 20     session.commit()
#      21
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py in commit(self)
#     941                 raise sa_exc.InvalidRequestError("No transaction is begun.")
#     942
# --> 943         self.transaction.commit()
#     944
#     945     def prepare(self):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py in commit(self)
#     463
#     464     def commit(self):
# --> 465         self._assert_active(prepared_ok=True)
#     466         if self._state is not PREPARED:
#     467             self._prepare_impl()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py in _assert_active(self, prepared_ok, rollback_ok, deactive_ok, closed_msg)
#     274                         "first issue Session.rollback()."
#     275                         " Original exception was: %s"
# --> 276                         % self._rollback_exception
#     277                     )
#     278                 elif not deactive_ok:
#
# InvalidRequestError: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (sqlite3.IntegrityError) UNIQUE constraint failed: fortune500_companies.name [SQL: 'INSERT INTO fortune500_companies (name, rank, country, num_employees, previous_rank, revenue_mil, revenue_change, profits_mil, profit_change, assets_mil) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)'] [parameters: ('State Grid', 2, 'China', 913546.0, '2', 348903, '0.107', '9533.4', '-0.004', 585278.0)] (Background on this error at: http://sqlalche.me/e/gkpj)

# %%
comapny_list = session.query(Fortune500)
for company in comapny_list:
    print(company.num_employees)
# Out:
# b'`\x18#\x00\x00\x00\x00\x00'
# b'\x8a\xf0\r\x00\x00\x00\x00\x00'
