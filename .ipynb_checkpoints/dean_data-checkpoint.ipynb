# %%
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd
import math
import pprint

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)


review_company = 'Apple'
url = "https://www.indeed.com/cmp/" + review_company + "/reviews"
browser.visit(url)
html = browser.html
#html

# %%
soup = BeautifulSoup(html, "html.parser")

pages_text = soup.find('span', {'class':'cmp-filter-result'}).text.strip().split()
pages_text
page_count = math.ceil(int(pages_text[1].replace(",", ""))/21)

# %%
column_list = ["company", "rating_number", "reviewer", "review_job_title", "review_job_location", \
                     "review_text", "review_date_created", "page_retrieved"]
export_df = pd.DataFrame(columns=column_list)

for i in range(1, page_count):

    for comment in soup.find_all('div', {'class':'cmp-review-container'}):
        rating_number = comment.find('div', {'class':'cmp-ratingNumber'}).text
        review_title = comment.find('div', {'class':'cmp-review-title'}).text
        reviewer = comment.find('span', {'class':'cmp-reviewer'}).text
        review_job_title = comment.find('span', {'class':'cmp-reviewer-job-title'}).text
        review_job_location = comment.find('span', {'class':'cmp-reviewer-job-location'}).text
        review_text = comment.find('span', {'class':'cmp-review-text'}).text
        review_date_created = comment.find('span', {'class':'cmp-review-date-created'}).text
        
        export_df = export_df.append(pd.DataFrame([[review_company, rating_number, reviewer, review_job_title, review_job_location,
                     review_text, review_date_created, i]], columns=column_list))
        print(rating_number)
        print(review_title)
        print(reviewer)
        print(review_job_title)
        print(review_job_location)
        print(review_text[1:60])
        print(review_date_created)
        print('Page ' + str(i))
    
    browser.click_link_by_partial_text('Next')
# Out:
# 5.0
# Great place to work
# Technical/ Sales Specialist
# Technical/ Sales Specialist (Former Employee) –
# Edison, NJ
# here is a lot to learn at this company. There is a lot of r
# September 26, 2018
# Page 1
# 3.0
# pays well
# Software Engineer
# Software Engineer (Current Employee) –
# Cupertino, CA
# our experience at Apple really depends only which group you
# October 29, 2018
# Page 1
# 5.0
# Productive and Enriching Environment
# Technical Specialist
# Technical Specialist (Current Employee) –
# Northridge, CA
# pple is a company that believes in their consumers and empl
# October 28, 2018
# Page 1
# 4.0
# Upbeat customer focused
# Technical Advisor
# Technical Advisor (Current Employee) –
# At Home
#  typical day at work is an 8-10 hour day, shifts based on q
# October 28, 2018
# Page 1
# 3.0
# Apple Distribution Center
# Material Handler 3
# Material Handler 3 (Former Employee) –
# Elk Grove, CA
#  was very excited when I started here. It is a well known c
# October 28, 2018
# Page 1
# 4.0
# it was a contractor position,
# Chat Specialist
# Chat Specialist (Former Employee) –
# San Antonio, TX
# verything about the system and materials to help with the j
# October 27, 2018
# Page 1
# 5.0
# Awesome place to work, lots of scope to learn & explore
# Sr Engineer/Individual contributor
# Sr Engineer/Individual contributor (Current Employee) –
# Sunnyvale, CA
#  enjoyed working at Apple Inc. Very helpful colleagues, fri
# October 26, 2018
# Page 1
# 5.0
# Rollercoaster
# LEAD GENIUS
# LEAD GENIUS (Former Employee) –
# Brea, CA
# he premier place to work in a retail environment. Apple mak
# October 26, 2018
# Page 1
# 5.0
# Fun, fast paced work environment
# Technical Specialist
# Technical Specialist (Current Employee) –
# Germantown, TN
#  literally get along with everyone at work and actually enj
# October 26, 2018
# Page 1
# 3.0
# Good benefits, but no advancement opportunity
# iTunes Support T1 Advisor
# iTunes Support T1 Advisor (Former Employee) –
# North Highlands, CA
# ood benefits, but no advancement opportunity Despite what t
# October 26, 2018
# Page 1
# 4.0
# It's a decent retail position with amazing benefits.
# TECHNICAL SPECIALIST
# TECHNICAL SPECIALIST (Former Employee) –
# Woodmere, OH
# pple is a nice company to work for. The people there are ty
# October 26, 2018
# Page 1
# 5.0
# Pressure
# Systems Engineer
# Systems Engineer (Former Employee) –
# Western, PA
# ressure from Management to reach sales goals.  Covered very
# October 26, 2018
# Page 1
# 5.0
# A Definite learning experience
# Apple Technical Advisor
# Apple Technical Advisor (Former Employee) –
# Remote
#  have learned so much working at Apple about the importance
# October 26, 2018
# Page 1
# 5.0
# Good place to work
# Sr Network Engineer
# Sr Network Engineer (Current Employee) –
# CA
# ood place to work and learn so much in the field of network
# October 26, 2018
# Page 1
# 4.0
# Apple
# Rd zone specialist to technical specialist
# Rd zone specialist to technical specialist (Former Employee) –
# Philadelphia, PA
# ypical day would be constant work flow 2 breaks 15 a piece
# October 25, 2018
# Page 1
# 5.0
# Remote work
# Senior Advisor
# Senior Advisor (Former Employee) –
# Council Bluffs, IA
#  worked through Kelly Connection for AppleCare as a tier 1
# October 25, 2018
# Page 1
# 3.0
# Competitive Place to work at
# Tier 1 Advisor
# Tier 1 Advisor (Current Employee) –
# Little Rock, AR
# ork from home for Apple through Conduent IncI work from hom
# October 25, 2018
# Page 1
# 5.0
# Solid Place
# Facilitated the Family Room Specialist
# Facilitated the Family Room Specialist (Former Employee) –
# Greenville, SC
# olid work environment that provided room to grow and climb
# October 25, 2018
# Page 1
# 4.0
# Fast paced, wirth exposure to technologies
# Deployment Specialist
# Deployment Specialist (Current Employee) –
# Sunnyvale, CA
# ast paced, wirth exposure to technologies as I mentioned, i
# October 25, 2018
# Page 1
# 5.0
# Incredible culture
# Genius
# Genius (Current Employee) –
# New York, NY
# he experience alone is worth working at AppleThe pay starts
# October 25, 2018
# Page 1
# 4.0
# Fast Paced
# AppleCare Advisor
# AppleCare Advisor (Former Employee) –
# Phoenix, AZ
# ast paced job , but overall I feel it provided good entry l
# October 24, 2018
# Page 1
# 5.0
# Great place to work
# Technical/ Sales Specialist
# Technical/ Sales Specialist (Former Employee) –
# Edison, NJ
# here is a lot to learn at this company. There is a lot of r
# September 26, 2018
# Page 2
# 3.0
# pays well
# Software Engineer
# Software Engineer (Current Employee) –
# Cupertino, CA
# our experience at Apple really depends only which group you
# October 29, 2018
# Page 2
# 5.0
# Productive and Enriching Environment
# Technical Specialist
# Technical Specialist (Current Employee) –
# Northridge, CA
# pple is a company that believes in their consumers and empl
# October 28, 2018
# Page 2
# 4.0
# Upbeat customer focused
# Technical Advisor
# Technical Advisor (Current Employee) –
# At Home
#  typical day at work is an 8-10 hour day, shifts based on q
# October 28, 2018
# Page 2
# 3.0
# Apple Distribution Center
# Material Handler 3
# Material Handler 3 (Former Employee) –
# Elk Grove, CA
#  was very excited when I started here. It is a well known c
# October 28, 2018
# Page 2
# 4.0
# it was a contractor position,
# Chat Specialist
# Chat Specialist (Former Employee) –
# San Antonio, TX
# verything about the system and materials to help with the j
# October 27, 2018
# Page 2
# 5.0
# Awesome place to work, lots of scope to learn & explore
# Sr Engineer/Individual contributor
# Sr Engineer/Individual contributor (Current Employee) –
# Sunnyvale, CA
#  enjoyed working at Apple Inc. Very helpful colleagues, fri
# October 26, 2018
# Page 2
# 5.0
# Rollercoaster
# LEAD GENIUS
# LEAD GENIUS (Former Employee) –
# Brea, CA
# he premier place to work in a retail environment. Apple mak
# October 26, 2018
# Page 2
# 5.0
# Fun, fast paced work environment
# Technical Specialist
# Technical Specialist (Current Employee) –
# Germantown, TN
#  literally get along with everyone at work and actually enj
# October 26, 2018
# Page 2
# 3.0
# Good benefits, but no advancement opportunity
# iTunes Support T1 Advisor
# iTunes Support T1 Advisor (Former Employee) –
# North Highlands, CA
# ood benefits, but no advancement opportunity Despite what t
# October 26, 2018
# Page 2
# 4.0
# It's a decent retail position with amazing benefits.
# TECHNICAL SPECIALIST
# TECHNICAL SPECIALIST (Former Employee) –
# Woodmere, OH
# pple is a nice company to work for. The people there are ty
# October 26, 2018
# Page 2
# 5.0
# Pressure
# Systems Engineer
# Systems Engineer (Former Employee) –
# Western, PA
# ressure from Management to reach sales goals.  Covered very
# October 26, 2018
# Page 2
# 5.0
# A Definite learning experience
# Apple Technical Advisor
# Apple Technical Advisor (Former Employee) –
# Remote
#  have learned so much working at Apple about the importance
# October 26, 2018
# Page 2
# 5.0
# Good place to work
# Sr Network Engineer
# Sr Network Engineer (Current Employee) –
# CA
# ood place to work and learn so much in the field of network
# October 26, 2018
# Page 2
# 4.0
# Apple
# Rd zone specialist to technical specialist
# Rd zone specialist to technical specialist (Former Employee) –
# Philadelphia, PA
# ypical day would be constant work flow 2 breaks 15 a piece
# October 25, 2018
# Page 2
# 5.0
# Remote work
# Senior Advisor
# Senior Advisor (Former Employee) –
# Council Bluffs, IA
#  worked through Kelly Connection for AppleCare as a tier 1
# October 25, 2018
# Page 2
# 3.0
# Competitive Place to work at
# Tier 1 Advisor
# Tier 1 Advisor (Current Employee) –
# Little Rock, AR
# ork from home for Apple through Conduent IncI work from hom
# October 25, 2018
# Page 2
# 5.0
# Solid Place
# Facilitated the Family Room Specialist
# Facilitated the Family Room Specialist (Former Employee) –
# Greenville, SC
# olid work environment that provided room to grow and climb
# October 25, 2018
# Page 2
# 4.0
# Fast paced, wirth exposure to technologies
# Deployment Specialist
# Deployment Specialist (Current Employee) –
# Sunnyvale, CA
# ast paced, wirth exposure to technologies as I mentioned, i
# October 25, 2018
# Page 2
# 5.0
# Incredible culture
# Genius
# Genius (Current Employee) –
# New York, NY
# he experience alone is worth working at AppleThe pay starts
# October 25, 2018
# Page 2
# 4.0
# Fast Paced
# AppleCare Advisor
# AppleCare Advisor (Former Employee) –
# Phoenix, AZ
# ast paced job , but overall I feel it provided good entry l
# October 24, 2018
# Page 2

# %%
export_file_name = './data/' + review_company + '_reviews.csv'

#export_df = export_df.set_index('company')
export_df.to_csv(export_file_name)
